# %%
import os
import pandas as pd
import gpxpy
import xml.etree.ElementTree as ET
from datetime import datetime, timezone

# %%
def standardize_activity_type(activity_type):
    activity_type = activity_type.lower()
    if activity_type in ['ride', 'biking', 'cycling']:
        return 'cycling'
    elif activity_type in ['run', 'running']:
        return 'running'
    elif activity_type in ['walk', 'walking']:
        return 'walking'
    else:
        return activity_type

# %%
def parse_gpx(file_path):
    with open(file_path, 'r') as gpx_file:
        gpx = gpxpy.parse(gpx_file)
    
    data = []
    activity_type = 'unknown'
    
    # Try to extract activity type from GPX metadata
    if gpx.tracks:
        for track in gpx.tracks:
            if track.type:
                activity_type = standardize_activity_type(track.type)
                break
    
    # If activity_type is still unknown, try parsing the XML directly
    if activity_type == 'unknown':
        try:
            tree = ET.parse(file_path)
            root = tree.getroot()
            namespace = {'gpx': 'http://www.topografix.com/GPX/1/1'}
            type_elem = root.find('.//gpx:trk/gpx:type', namespace)
            if type_elem is not None and type_elem.text:
                activity_type = standardize_activity_type(type_elem.text)
        except ET.ParseError:
            print(f"Warning: Unable to parse XML in {file_path}")
    
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                data.append({
                    'timestamp': point.time.replace(tzinfo=timezone.utc) if point.time else None,
                    'latitude': point.latitude,
                    'longitude': point.longitude,
                    'elevation': point.elevation,
                    'heart_rate': point.extensions[0].get('hr', None) if point.extensions else None,
                    'file_name': os.path.basename(file_path),
                    'activity_type': activity_type
                })
    
    return pd.DataFrame(data)

# %%
def parse_tcx(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    
    xml_start = content.find('<?xml')
    if xml_start == -1:
        raise ValueError("No XML declaration found in the file")
    
    root = ET.fromstring(content[xml_start:])
    
    namespace = {'ns': 'http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2'}
    
    data = []
    activity_type = 'unknown'
    
    # Try to extract activity type from TCX
    activity_elem = root.find('.//ns:Activity', namespace)
    if activity_elem is not None:
        activity_type = standardize_activity_type(activity_elem.get('Sport', 'unknown'))
    
    for trackpoint in root.findall('.//ns:Trackpoint', namespace):
        time = trackpoint.find('ns:Time', namespace)
        position = trackpoint.find('ns:Position', namespace)
        elevation = trackpoint.find('ns:AltitudeMeters', namespace)
        heart_rate = trackpoint.find('.//ns:HeartRateBpm/ns:Value', namespace)
        
        if time is not None:
            point_data = {
                'timestamp': datetime.fromisoformat(time.text).replace(tzinfo=timezone.utc),
                'file_name': os.path.basename(file_path),
                'activity_type': activity_type
            }
            
            if position is not None:
                point_data['latitude'] = float(position.find('ns:LatitudeDegrees', namespace).text)
                point_data['longitude'] = float(position.find('ns:LongitudeDegrees', namespace).text)
            
            if elevation is not None:
                point_data['elevation'] = float(elevation.text)
            
            if heart_rate is not None:
                point_data['heart_rate'] = int(heart_rate.text)
            
            data.append(point_data)
    
    return pd.DataFrame(data)

# %%
def process_all_files():
    all_data = []
    
    for file in os.listdir('.'):
        if file.endswith('.gpx'):
            try:
                df = parse_gpx(file)
                all_data.append(df)
                print(f"Successfully processed GPX file: {file}")
            except Exception as e:
                print(f"Error processing GPX file {file}: {e}")
        
        elif file.endswith('.tcx'):
            try:
                df = parse_tcx(file)
                all_data.append(df)
                print(f"Successfully processed TCX file: {file}")
            except Exception as e:
                print(f"Error processing TCX file {file}: {e}")
    
    if not all_data:
        print("No GPX or TCX files found in the current directory.")
        return None
    
    combined_data = pd.concat(all_data, ignore_index=True)
    combined_data = combined_data.sort_values('timestamp')
    
    return combined_data

# %%
# Process all files and get combined data
all_activities_data = process_all_files()

if all_activities_data is not None:
    print("\nCombined Data Summary:")
    print(all_activities_data.describe())
    
    print("\nNumber of activities:", all_activities_data['file_name'].nunique())
    print("Date range:", all_activities_data['timestamp'].min().date(), "to", all_activities_data['timestamp'].max().date())
    
    print("\nActivity Types:")
    print(all_activities_data['activity_type'].value_counts())
    
    # Save combined data to CSV
    all_activities_data.to_csv('all_activities_data.csv', index=False)
    print("\nAll data has been saved to 'all_activities_data.csv'")
else:
    print("No data to process.")
# Out:
# Successfully processed TCX file: 10006096920.tcx
# Successfully processed TCX file: 10071074570.tcx
# Successfully processed TCX file: 10072554088.tcx
# Successfully processed TCX file: 10075275124.tcx
# Successfully processed TCX file: 10081995809.tcx
# Successfully processed TCX file: 10092773149.tcx
# Successfully processed TCX file: 10092773210.tcx
# Successfully processed TCX file: 10118979612.tcx
# Successfully processed TCX file: 10118979697.tcx
# Successfully processed TCX file: 10118979773.tcx
# Successfully processed TCX file: 10124686569.tcx
# Successfully processed TCX file: 10124686608.tcx
# Successfully processed TCX file: 10129599077.tcx
# Successfully processed TCX file: 10131224403.tcx
# Successfully processed TCX file: 10132062265.tcx
# Successfully processed TCX file: 10140384350.tcx
# Successfully processed TCX file: 10143559171.tcx
# Successfully processed TCX file: 10155282539.tcx
# Successfully processed TCX file: 10163154485.tcx
# Successfully processed TCX file: 10165231865.tcx
# Successfully processed TCX file: 10172175547.tcx
# Successfully processed TCX file: 10172175558.tcx
# Successfully processed TCX file: 10180555520.tcx
# Successfully processed TCX file: 10180555550.tcx
# Successfully processed TCX file: 10187087093.tcx
# Successfully processed TCX file: 10190748534.tcx
# Successfully processed TCX file: 10210063207.tcx
# Successfully processed TCX file: 10211731406.tcx
# Successfully processed TCX file: 10244239110.tcx
# Successfully processed TCX file: 10253952119.tcx
# Successfully processed TCX file: 10255845983.tcx
# Successfully processed TCX file: 10259461170.tcx
# Successfully processed TCX file: 10264957828.tcx
# Successfully processed TCX file: 10264957838.tcx
# Successfully processed TCX file: 10270451133.tcx
# Successfully processed TCX file: 10271474140.tcx
# Successfully processed TCX file: 10279725198.tcx
# Successfully processed TCX file: 10279725237.tcx
# Successfully processed TCX file: 10279725374.tcx
# Successfully processed TCX file: 10282667929.tcx
# Successfully processed TCX file: 10283094667.tcx
# Successfully processed TCX file: 10298815418.tcx
# Successfully processed TCX file: 10304000061.tcx
# Successfully processed TCX file: 10306143446.tcx
# Successfully processed TCX file: 10310372860.tcx
# Successfully processed TCX file: 10318687873.tcx
# Successfully processed TCX file: 10318687896.tcx
# Successfully processed TCX file: 10318687919.tcx
# Successfully processed TCX file: 10323150287.tcx
# Successfully processed TCX file: 10327411506.tcx
# Successfully processed TCX file: 10327411568.tcx
# Successfully processed TCX file: 10331446132.tcx
# Successfully processed TCX file: 10349381178.tcx
# Successfully processed TCX file: 10366937794.tcx
# Successfully processed TCX file: 10369449073.tcx
# Successfully processed TCX file: 10376116167.tcx
# Successfully processed TCX file: 10380713835.tcx
# Successfully processed TCX file: 10409443144.tcx
# Successfully processed TCX file: 10409443155.tcx
# Successfully processed TCX file: 10460580799.tcx
# Successfully processed TCX file: 10499973620.tcx
# Successfully processed TCX file: 10503608730.tcx
# Successfully processed TCX file: 10511630415.tcx
# Successfully processed TCX file: 10527772860.tcx
# Successfully processed TCX file: 10527772917.tcx
# Successfully processed TCX file: 10527773004.tcx
# Successfully processed TCX file: 10536648088.tcx
# Successfully processed TCX file: 10551474552.tcx
# Successfully processed TCX file: 10551474598.tcx
# Successfully processed TCX file: 10582500199.tcx
# Successfully processed TCX file: 10582500223.tcx
# Successfully processed TCX file: 10582500286.tcx
# Successfully processed TCX file: 10601900587.tcx
# Successfully processed TCX file: 10601900643.tcx
# Successfully processed TCX file: 10609058606.tcx
# Successfully processed TCX file: 10615172834.tcx
# Successfully processed TCX file: 10645438163.tcx
# Successfully processed TCX file: 10645438214.tcx
# Successfully processed TCX file: 10657222416.tcx
# Successfully processed TCX file: 10658443980.tcx
# Successfully processed TCX file: 10672849039.tcx
# Successfully processed TCX file: 10683395324.tcx
# Successfully processed TCX file: 10683395372.tcx
# Successfully processed TCX file: 10689395934.tcx
# Successfully processed TCX file: 10689395968.tcx
# Successfully processed TCX file: 10691854672.tcx
# Successfully processed TCX file: 10699991148.tcx
# Successfully processed TCX file: 10699991154.tcx
# Successfully processed TCX file: 10704628571.tcx
# Successfully processed TCX file: 10704628599.tcx
# Successfully processed TCX file: 10723730593.tcx
# Successfully processed TCX file: 10740815456.tcx
# Successfully processed TCX file: 10740815557.tcx
# Successfully processed TCX file: 10747790161.tcx
# Successfully processed TCX file: 10763431371.tcx
# Successfully processed TCX file: 10779715031.tcx
# Successfully processed TCX file: 10779715115.tcx
# Successfully processed TCX file: 10781337919.tcx
# Successfully processed TCX file: 11425088507.tcx
# Successfully processed TCX file: 11425089137.tcx
# Successfully processed TCX file: 11459275252.tcx
# Successfully processed TCX file: 11469131254.tcx
# Successfully processed TCX file: 11482096278.tcx
# Successfully processed TCX file: 11482096289.tcx
# Successfully processed TCX file: 11492670070.tcx
# Successfully processed TCX file: 11494398104.tcx
# Successfully processed TCX file: 11570516112.tcx
# Successfully processed TCX file: 11570516130.tcx
# Successfully processed TCX file: 11596835120.tcx
# Successfully processed TCX file: 11596835145.tcx
# Successfully processed TCX file: 11603662677.tcx
# Successfully processed TCX file: 11631705748.tcx
# Successfully processed TCX file: 11634486132.tcx
# Successfully processed TCX file: 11642658967.tcx
# Successfully processed TCX file: 11642659018.tcx
# Successfully processed TCX file: 11642659100.tcx
# Successfully processed TCX file: 11660698344.tcx
# Successfully processed TCX file: 11660698387.tcx
# Successfully processed TCX file: 11670218302.tcx
# Successfully processed TCX file: 11670218318.tcx
# Successfully processed TCX file: 11673193989.tcx
# Successfully processed TCX file: 11675921468.tcx
# Successfully processed TCX file: 11702011891.tcx
# Successfully processed TCX file: 11702011945.tcx
# Successfully processed TCX file: 11705270152.tcx
# Successfully processed TCX file: 11708996074.tcx
# Successfully processed TCX file: 11712140228.tcx
# Successfully processed TCX file: 11772094319.tcx
# Successfully processed TCX file: 11772094326.tcx
# Successfully processed TCX file: 11805351679.tcx
# Successfully processed TCX file: 11805351726.tcx
# Successfully processed TCX file: 11820817492.tcx
# Successfully processed TCX file: 11820817503.tcx
# Successfully processed TCX file: 11836490386.tcx
# Successfully processed TCX file: 11851082199.tcx
# Successfully processed TCX file: 11851082258.tcx
# Successfully processed TCX file: 11885754179.tcx
# Successfully processed TCX file: 11889131899.tcx
# Successfully processed TCX file: 11903426654.tcx
# Successfully processed TCX file: 11903426712.tcx
# Successfully processed TCX file: 11912537968.tcx
# Successfully processed TCX file: 11912538002.tcx
# Successfully processed TCX file: 11916075320.tcx
# Successfully processed TCX file: 11918107283.tcx
# Successfully processed TCX file: 11928427963.tcx
# Successfully processed TCX file: 11955283540.tcx
# Successfully processed TCX file: 11962808305.tcx
# Successfully processed TCX file: 11962808320.tcx
# Successfully processed TCX file: 11962808470.tcx
# Successfully processed TCX file: 11965020212.tcx
# Successfully processed TCX file: 11965020352.tcx
# Successfully processed TCX file: 11977201209.tcx
# Successfully processed TCX file: 11986494286.tcx
# Successfully processed TCX file: 11986494336.tcx
# Successfully processed TCX file: 12029406989.tcx
# Successfully processed TCX file: 12029407019.tcx
# Successfully processed TCX file: 12042495812.tcx
# Successfully processed TCX file: 12042495822.tcx
# Successfully processed TCX file: 12042495839.tcx
# Successfully processed TCX file: 12042495848.tcx
# Successfully processed TCX file: 12056201565.tcx
# Successfully processed TCX file: 12056201627.tcx
# Successfully processed TCX file: 12086436510.tcx
# Successfully processed TCX file: 12086436537.tcx
# Successfully processed TCX file: 12086436685.tcx
# Successfully processed TCX file: 12086436688.tcx
# Successfully processed TCX file: 12086436717.tcx
# Successfully processed TCX file: 12086436747.tcx
# Successfully processed TCX file: 12086436764.tcx
# Successfully processed TCX file: 12086436811.tcx
# Successfully processed TCX file: 12086436889.tcx
# Successfully processed TCX file: 12086699544.tcx
# Successfully processed TCX file: 12094426686.tcx
# Successfully processed TCX file: 12094426748.tcx
# Successfully processed TCX file: 12118041203.tcx
# Successfully processed TCX file: 12118041258.tcx
# Successfully processed TCX file: 12121937448.tcx
# Successfully processed TCX file: 12125493797.tcx
# Successfully processed TCX file: 12128815280.tcx
# Successfully processed TCX file: 12133375796.tcx
# Successfully processed TCX file: 12137090768.tcx
# Successfully processed TCX file: 12137513553.tcx
# Successfully processed TCX file: 12144078496.tcx
# Successfully processed TCX file: 12145686029.tcx
# Successfully processed TCX file: 12150193816.tcx
# Successfully processed TCX file: 12153449311.tcx
# Successfully processed TCX file: 12187078341.tcx
# Successfully processed TCX file: 12187078357.tcx
# Successfully processed TCX file: 12187078386.tcx
# Successfully processed TCX file: 12187078467.tcx
# Successfully processed TCX file: 12196386280.tcx
# Successfully processed TCX file: 12196386287.tcx
# Successfully processed TCX file: 12198172785.tcx
# Successfully processed TCX file: 12202376974.tcx
# Successfully processed TCX file: 12226020432.tcx
# Successfully processed TCX file: 12226020464.tcx
# Successfully processed TCX file: 12230947707.tcx
# Successfully processed TCX file: 12230947793.tcx
# Successfully processed TCX file: 12234992384.tcx
# Successfully processed TCX file: 12254941790.tcx
# Successfully processed TCX file: 12254941819.tcx
# Successfully processed TCX file: 12254941920.tcx
# Successfully processed TCX file: 12257939023.tcx
# Successfully processed TCX file: 12262774635.tcx
# Successfully processed TCX file: 12283607489.tcx
# Successfully processed TCX file: 12283607533.tcx
# Successfully processed TCX file: 12283607551.tcx
# Successfully processed TCX file: 12283607571.tcx
# Successfully processed TCX file: 12338239639.tcx
# Successfully processed TCX file: 12347100510.tcx
# Successfully processed TCX file: 12347100532.tcx
# Successfully processed TCX file: 12370320999.tcx
# Successfully processed TCX file: 12370321031.tcx
# Successfully processed TCX file: 12406151731.tcx
# Successfully processed TCX file: 12406151777.tcx
# Successfully processed TCX file: 12406151940.tcx
# Successfully processed TCX file: 12406152071.tcx
# Successfully processed TCX file: 12412823307.tcx
# Successfully processed TCX file: 12412823327.tcx
# Successfully processed TCX file: 12417403093.tcx
# Successfully processed TCX file: 12428620062.tcx
# Successfully processed TCX file: 12428620091.tcx
# Successfully processed TCX file: 12428620128.tcx
# Successfully processed TCX file: 12428620186.tcx
# Successfully processed TCX file: 12435309927.tcx
# Successfully processed TCX file: 12435309944.tcx
# Successfully processed TCX file: 12450143050.tcx
# Successfully processed TCX file: 12450143135.tcx
# Successfully processed TCX file: 12459589430.tcx
# Successfully processed TCX file: 12459589492.tcx
# Successfully processed TCX file: 12468817560.tcx
# Successfully processed TCX file: 12468817581.tcx
# Successfully processed TCX file: 12477070279.tcx
# Successfully processed TCX file: 12487129956.tcx
# Successfully processed TCX file: 12495018845.tcx
# Successfully processed TCX file: 12504070397.tcx
# Successfully processed TCX file: 12504070471.tcx
# Successfully processed TCX file: 12516402645.tcx
# Successfully processed TCX file: 12516402666.tcx
# Successfully processed TCX file: 12521944961.tcx
# Successfully processed TCX file: 12532699038.tcx
# Successfully processed TCX file: 12532699052.tcx
# Successfully processed TCX file: 12555961595.tcx
# Successfully processed TCX file: 12574934391.tcx
# Successfully processed TCX file: 12578572769.tcx
# Successfully processed TCX file: 12589179362.tcx
# Successfully processed TCX file: 12589179535.tcx
# Successfully processed TCX file: 12592673484.tcx
# Successfully processed TCX file: 12597350689.tcx
# Successfully processed TCX file: 12600017316.tcx
# Successfully processed TCX file: 12603516188.tcx
# Successfully processed TCX file: 12611764847.tcx
# Successfully processed TCX file: 12611764864.tcx
# Successfully processed TCX file: 12620301944.tcx
# Successfully processed TCX file: 12620301966.tcx
# Successfully processed TCX file: 12621329921.tcx
# Successfully processed TCX file: 12640210955.tcx
# Successfully processed TCX file: 12640210960.tcx
# Successfully processed TCX file: 12658131686.tcx
# Successfully processed TCX file: 12658131719.tcx
# Successfully processed TCX file: 12671061507.tcx
# Successfully processed TCX file: 12671061508.tcx
# Successfully processed TCX file: 12708472391.tcx
# Successfully processed TCX file: 12708472397.tcx
# Successfully processed TCX file: 12708472487.tcx
# Successfully processed TCX file: 12714541192.tcx
# Successfully processed TCX file: 12716839371.tcx
# Successfully processed TCX file: 12722386130.tcx
# Successfully processed TCX file: 12727161036.tcx
# Successfully processed TCX file: 12729932652.tcx
# Successfully processed TCX file: 12739089091.tcx
# Successfully processed TCX file: 12739089098.tcx
# Successfully processed TCX file: 12770180684.tcx
# Successfully processed TCX file: 12770180798.tcx
# Successfully processed TCX file: 12777422598.tcx
# Successfully processed TCX file: 12777422675.tcx
# Successfully processed GPX file: 4907245420.gpx
# Successfully processed GPX file: 4908669872.gpx
# Successfully processed GPX file: 4947464404.gpx
# Successfully processed GPX file: 4985608340.gpx
# Successfully processed GPX file: 4992087101.gpx
# Successfully processed GPX file: 5026402111.gpx
# Successfully processed GPX file: 5027840251.gpx
# Successfully processed TCX file: 5387185118.tcx
# Successfully processed TCX file: 5399591723.tcx
# Successfully processed TCX file: 5400109105.tcx
# Successfully processed TCX file: 5403138719.tcx
# Successfully processed TCX file: 5404632093.tcx
# Successfully processed TCX file: 5447678839.tcx
# Successfully processed TCX file: 5448481560.tcx
# Successfully processed TCX file: 5483109407.tcx
# Successfully processed TCX file: 5483694589.tcx
# Successfully processed TCX file: 5608064200.tcx
# Successfully processed TCX file: 5608816030.tcx
# Successfully processed TCX file: 5648566211.tcx
# Successfully processed TCX file: 5648813508.tcx
# Successfully processed TCX file: 5649380183.tcx
# Successfully processed TCX file: 5652986170.tcx
# Successfully processed TCX file: 5653068894.tcx
# Successfully processed TCX file: 5654950116.tcx
# Successfully processed TCX file: 5655575957.tcx
# Successfully processed TCX file: 5693507520.tcx
# Successfully processed TCX file: 5693592619.tcx
# Successfully processed TCX file: 5695358435.tcx
# Successfully processed TCX file: 5732591707.tcx
# Successfully processed TCX file: 5734053370.tcx
# Successfully processed TCX file: 5734772190.tcx
# Successfully processed TCX file: 5783031968.tcx
# Error processing GPX file 5806469605.gpx: Error parsing XML: syntax error: line 1, column 0
# Successfully processed TCX file: 5816111928.tcx
# Successfully processed TCX file: 5816571202.tcx
# Successfully processed TCX file: 5818033519.tcx
# Successfully processed TCX file: 5855271252.tcx
# Successfully processed TCX file: 5969550925.tcx
# Successfully processed TCX file: 5971790442.tcx
# Successfully processed TCX file: 6007745874.tcx
# Successfully processed TCX file: 6009768776.tcx
# Error processing GPX file 6019417347.gpx: Error parsing XML: syntax error: line 1, column 0
# Successfully processed TCX file: 6047706916.tcx
# Successfully processed TCX file: 6049128438.tcx
# Successfully processed TCX file: 6086230124.tcx
# Successfully processed TCX file: 6087708345.tcx
# Successfully processed TCX file: 6120247264.tcx
# Successfully processed TCX file: 6121230179.tcx
# Successfully processed TCX file: 6124063714.tcx
# Successfully processed TCX file: 6126490912.tcx
# Successfully processed TCX file: 6163698336.tcx
# Error processing GPX file 6174759897.gpx: latitude is mandatory in None (got None)
# Successfully processed TCX file: 6205505256.tcx
# Successfully processed TCX file: 6206703343.tcx
# Successfully processed TCX file: 6242741894.tcx
# Successfully processed TCX file: 6245178827.tcx
# Successfully processed TCX file: 6325329761.tcx
# Successfully processed TCX file: 6397625367.tcx
# Successfully processed GPX file: 6397695345.gpx
# Successfully processed TCX file: 6401834741.tcx
# Successfully processed GPX file: 6433771260.gpx
# Successfully processed GPX file: 6434268880.gpx
# Successfully processed GPX file: 6437869248.gpx
# Error processing GPX file 6437869272.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6439707367.gpx
# Successfully processed GPX file: 6440311489.gpx
# Successfully processed GPX file: 6447358760.gpx
# Successfully processed GPX file: 6447358966.gpx
# Successfully processed GPX file: 6548077964.gpx
# Successfully processed GPX file: 6568930161.gpx
# Successfully processed GPX file: 6577065433.gpx
# Successfully processed GPX file: 6581878358.gpx
# Error processing GPX file 6582483894.gpx: latitude is mandatory in None (got None)
# Error processing GPX file 6582483912.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6583371391.gpx
# Successfully processed GPX file: 6583371394.gpx
# Successfully processed GPX file: 6583371402.gpx
# Successfully processed GPX file: 6598019174.gpx
# Successfully processed GPX file: 6598405046.gpx
# Successfully processed GPX file: 6611594874.gpx
# Error processing GPX file 6612093343.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6612523084.gpx
# Successfully processed GPX file: 6617080605.gpx
# Error processing GPX file 6617080695.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6617952810.gpx
# Successfully processed GPX file: 6624592066.gpx
# Successfully processed GPX file: 6624592124.gpx
# Successfully processed GPX file: 6632580104.gpx
# Successfully processed GPX file: 6632580131.gpx
# Successfully processed GPX file: 6632718267.gpx
# Successfully processed GPX file: 6649876001.gpx
# Successfully processed GPX file: 6650256950.gpx
# Error processing GPX file 6651143374.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6651643944.gpx
# Successfully processed GPX file: 6655853567.gpx
# Successfully processed GPX file: 6678881752.gpx
# Error processing GPX file 6679147920.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6680505509.gpx
# Successfully processed GPX file: 6684371299.gpx
# Successfully processed GPX file: 6684371333.gpx
# Error processing GPX file 6684371371.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6685017802.gpx
# Error processing GPX file 6742350356.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6747584147.gpx
# Successfully processed GPX file: 6774031802.gpx
# Successfully processed GPX file: 6777837900.gpx
# Error processing GPX file 6777837931.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6778707971.gpx
# Successfully processed GPX file: 6807407066.gpx
# Error processing GPX file 6807407141.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6807407306.gpx
# Successfully processed GPX file: 6808181912.gpx
# Error processing GPX file 6828462250.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6841216631.gpx
# Successfully processed GPX file: 6845782619.gpx
# Successfully processed GPX file: 6846702557.gpx
# Successfully processed GPX file: 6864954379.gpx
# Successfully processed GPX file: 6872829047.gpx
# Successfully processed GPX file: 6883595077.gpx
# Successfully processed GPX file: 6894024405.gpx
# Successfully processed GPX file: 6897988100.gpx
# Successfully processed GPX file: 6904573971.gpx
# Successfully processed GPX file: 6909591227.gpx
# Error processing GPX file 6909591284.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6910367972.gpx
# Successfully processed GPX file: 6915771134.gpx
# Successfully processed GPX file: 6942555112.gpx
# Successfully processed GPX file: 6946509797.gpx
# Error processing GPX file 6947573152.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6981581509.gpx
# Successfully processed GPX file: 6981581579.gpx
# Successfully processed GPX file: 6986094596.gpx
# Error processing GPX file 6986094717.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6986396938.gpx
# Error processing GPX file 6987157261.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 6987884218.gpx
# Successfully processed GPX file: 7103524795.gpx
# Successfully processed GPX file: 7135524745.gpx
# Successfully processed GPX file: 7139379923.gpx
# Error processing GPX file 7139380046.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7139380244.gpx
# Error processing GPX file 7139380355.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7139935431.gpx
# Successfully processed GPX file: 7178090960.gpx
# Error processing GPX file 7178091030.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7178091071.gpx
# Successfully processed GPX file: 7209771112.gpx
# Successfully processed GPX file: 7319819745.gpx
# Successfully processed GPX file: 7334569010.gpx
# Successfully processed GPX file: 7360604609.gpx
# Successfully processed GPX file: 7382590898.gpx
# Successfully processed GPX file: 7394871164.gpx
# Successfully processed GPX file: 7409036577.gpx
# Successfully processed GPX file: 7420945560.gpx
# Successfully processed GPX file: 7430908555.gpx
# Successfully processed GPX file: 7434848770.gpx
# Successfully processed GPX file: 7441596874.gpx
# Error processing GPX file 7441596882.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7442390275.gpx
# Successfully processed GPX file: 7481934491.gpx
# Error processing GPX file 7481934595.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7482650671.gpx
# Successfully processed GPX file: 7488194687.gpx
# Successfully processed GPX file: 7564332624.gpx
# Successfully processed GPX file: 7582913105.gpx
# Successfully processed GPX file: 7625178826.gpx
# Successfully processed GPX file: 7626997942.gpx
# Successfully processed GPX file: 7630711863.gpx
# Successfully processed GPX file: 7652990572.gpx
# Error processing GPX file 7652990897.gpx: latitude is mandatory in None (got None)
# Successfully processed GPX file: 7653696766.gpx
# Successfully processed GPX file: 7734168378.gpx
# Successfully processed GPX file: 7752729990.gpx
# Successfully processed GPX file: 7768372317.gpx
# Successfully processed GPX file: 7774886716.gpx
# Successfully processed GPX file: 7776406809.gpx
# Successfully processed GPX file: 7805031974.gpx
# Successfully processed GPX file: 7821128112.gpx
# Successfully processed GPX file: 7850946935.gpx
# Successfully processed GPX file: 7851863113.gpx
# Successfully processed GPX file: 7856645760.gpx
# Successfully processed GPX file: 7861180501.gpx
# Successfully processed GPX file: 7892312482.gpx
# Successfully processed GPX file: 7898265788.gpx
# Successfully processed GPX file: 7901961726.gpx
# Successfully processed GPX file: 7902818142.gpx
# Successfully processed GPX file: 7931394041.gpx
# Successfully processed GPX file: 7938785611.gpx
# Successfully processed GPX file: 7957597987.gpx
# Successfully processed GPX file: 7974180359.gpx
# Successfully processed GPX file: 7980375238.gpx
# Successfully processed GPX file: 7996968339.gpx
# Successfully processed GPX file: 8004740230.gpx
# Successfully processed GPX file: 8238120191.gpx
# Successfully processed GPX file: 8241376834.gpx
# Successfully processed GPX file: 8244558026.gpx
# Successfully processed GPX file: 8251434085.gpx
# Successfully processed GPX file: 8251434285.gpx
# Successfully processed GPX file: 8253885325.gpx
# Successfully processed GPX file: 8257488984.gpx
# Successfully processed TCX file: 8310464872.tcx
# Successfully processed TCX file: 8317781794.tcx
# Successfully processed TCX file: 8324612908.tcx
# Successfully processed TCX file: 8349236238.tcx
# Successfully processed TCX file: 8365595836.tcx
# Successfully processed TCX file: 8400052007.tcx
# Successfully processed TCX file: 8407248934.tcx
# Successfully processed TCX file: 8419753365.tcx
# Successfully processed TCX file: 8435637272.tcx
# Successfully processed TCX file: 8438518748.tcx
# Successfully processed TCX file: 8441132029.tcx
# Successfully processed TCX file: 8479836541.tcx
# Successfully processed TCX file: 8521271293.tcx
# Successfully processed TCX file: 8522761988.tcx
# Successfully processed TCX file: 8534210148.tcx
# Successfully processed TCX file: 8553007500.tcx
# Successfully processed TCX file: 8569030122.tcx
# Successfully processed TCX file: 8610485855.tcx
# Successfully processed TCX file: 8615618545.tcx
# Successfully processed TCX file: 8648263701.tcx
# Successfully processed TCX file: 8724165290.tcx
# Successfully processed TCX file: 8738524015.tcx
# Successfully processed TCX file: 8743019543.tcx
# Successfully processed TCX file: 8754466055.tcx
# Successfully processed TCX file: 8764701598.tcx
# Successfully processed TCX file: 8768649506.tcx
# Successfully processed TCX file: 8792108621.tcx
# Successfully processed TCX file: 8821677659.tcx
# Successfully processed TCX file: 8848140555.tcx
# Successfully processed TCX file: 8930934338.tcx
# Successfully processed TCX file: 8939422035.tcx
# Successfully processed TCX file: 8958258907.tcx
# Successfully processed TCX file: 8996288738.tcx
# Successfully processed TCX file: 9001137799.tcx
# Successfully processed TCX file: 9027349496.tcx
# Successfully processed TCX file: 9034546195.tcx
# Successfully processed TCX file: 9034546216.tcx
# Successfully processed TCX file: 9043757456.tcx
# Successfully processed TCX file: 9062861377.tcx
# Successfully processed TCX file: 9086307369.tcx
# Successfully processed TCX file: 9090627955.tcx
# Successfully processed TCX file: 9090628271.tcx
# Successfully processed TCX file: 9095281189.tcx
# Successfully processed TCX file: 9098277159.tcx
# Successfully processed TCX file: 9114173002.tcx
# Successfully processed TCX file: 9127397297.tcx
# Successfully processed TCX file: 9136410724.tcx
# Successfully processed TCX file: 9172468870.tcx
# Successfully processed TCX file: 9172468997.tcx
# Successfully processed TCX file: 9178145688.tcx
# Successfully processed TCX file: 9200920531.tcx
# Successfully processed TCX file: 9206368197.tcx
# Successfully processed TCX file: 9221287817.tcx
# Successfully processed TCX file: 9256413239.tcx
# Successfully processed TCX file: 9256413381.tcx
# Successfully processed GPX file: 9264127087.gpx
# Successfully processed TCX file: 9296512728.tcx
# Successfully processed TCX file: 9309566374.tcx
# Successfully processed TCX file: 9309566415.tcx
# Successfully processed TCX file: 9318018520.tcx
# Successfully processed TCX file: 9319869807.tcx
# Successfully processed TCX file: 9396270305.tcx
# Successfully processed TCX file: 9396270394.tcx
# Successfully processed TCX file: 9402279550.tcx
# Successfully processed TCX file: 9402279617.tcx
# Successfully processed TCX file: 9405246437.tcx
# Successfully processed TCX file: 9406726131.tcx
# Successfully processed TCX file: 9411612581.tcx
# Successfully processed TCX file: 9411613301.tcx
# Successfully processed TCX file: 9420522244.tcx
# Successfully processed TCX file: 9429108721.tcx
# Successfully processed TCX file: 9438106637.tcx
# Successfully processed TCX file: 9438106668.tcx
# Successfully processed TCX file: 9443362270.tcx
# Successfully processed TCX file: 9443362314.tcx
# Successfully processed TCX file: 9456791460.tcx
# Successfully processed TCX file: 9456791538.tcx
# Successfully processed TCX file: 9560286755.tcx
# Successfully processed TCX file: 9649424367.tcx
# Successfully processed TCX file: 9652094422.tcx
# Successfully processed TCX file: 9654787747.tcx
# Successfully processed TCX file: 9660279569.tcx
# Successfully processed TCX file: 9662257397.tcx
# Successfully processed TCX file: 9675290891.tcx
# Successfully processed TCX file: 9681779111.tcx
# Successfully processed TCX file: 9700632008.tcx
# Successfully processed TCX file: 9700632029.tcx
# Successfully processed TCX file: 9746099629.tcx
# Successfully processed TCX file: 9751655694.tcx
# Successfully processed TCX file: 9764127576.tcx
# Successfully processed TCX file: 9777683505.tcx
# Successfully processed TCX file: 9790270795.tcx
# Successfully processed TCX file: 9793751087.tcx
# Successfully processed TCX file: 9813499470.tcx
# Successfully processed TCX file: 9816925991.tcx
# Successfully processed TCX file: 9820141422.tcx
# Successfully processed TCX file: 9833710775.tcx
# Successfully processed TCX file: 9840203221.tcx
# Successfully processed TCX file: 9846019305.tcx
# Successfully processed TCX file: 9846019316.tcx
# Successfully processed TCX file: 9846019427.tcx
# Successfully processed TCX file: 9854422204.tcx
# Successfully processed TCX file: 9855286255.tcx
# Successfully processed TCX file: 9863781275.tcx
# Successfully processed TCX file: 9867027911.tcx
# Successfully processed TCX file: 9886941429.tcx
# Successfully processed TCX file: 9888937007.tcx
# Successfully processed TCX file: 9901368799.tcx
# Successfully processed TCX file: 9902172315.tcx
# Successfully processed TCX file: 9910542214.tcx
# Successfully processed TCX file: 9915035793.tcx
# Successfully processed TCX file: 9932675375.tcx
# Successfully processed TCX file: 9933320876.tcx
# Successfully processed TCX file: 9935316536.tcx
# Successfully processed TCX file: 9950689022.tcx
# Successfully processed TCX file: 9950689030.tcx
# Successfully processed TCX file: 9952827024.tcx
# Successfully processed TCX file: 9956811621.tcx
# Successfully processed TCX file: 9959921599.tcx
# Successfully processed TCX file: 9973757917.tcx
# Successfully processed TCX file: 9974666863.tcx
# Successfully processed TCX file: 9981254585.tcx
# Successfully processed TCX file: 9981254621.tcx
# Successfully processed TCX file: 9990186204.tcx
# Successfully processed TCX file: 9990186206.tcx
# Successfully processed TCX file: 9993872119.tcx
# Successfully processed TCX file: 9995795879.tcx
# C:\Users\leoko\AppData\Local\Temp\ipykernel_7336\2142983829.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_data = pd.concat(all_data, ignore_index=True)
# Combined Data Summary:
#            latitude     longitude     heart_rate      elevation
# count  1.507683e+06  1.507683e+06  435072.000000  581215.000000
# mean   2.027047e+01 -7.632772e+01     114.594948    2577.884147
# std    1.894437e+01  2.740995e+00      35.106919     245.260014
# min    4.583551e+00 -7.976345e+01      43.000000    -149.000000
# 25%    4.699268e+00 -7.968901e+01      83.000000    2566.000000
# 50%    4.747527e+00 -7.409178e+01     114.000000    2581.000000
# 75%    4.354257e+01 -7.405813e+01     143.000000    2608.000000
# max    4.363600e+01 -7.376197e+01     199.000000    3041.000000
#
# Number of activities: 578
# Date range: 2021-03-07 to 2024-07-26
#
# Activity Types:
# activity_type
# cycling    1492528
# walking      14785
# running       1522
# other          589
# swim           186
# Name: count, dtype: int64
#
# All data has been saved to 'all_activities_data.csv'

# %%
#from the csv file I want to see all the activities that are tagged as unknown, but only show the file name and the activity type, and if the file name appears more than once, only show it once.  
#I also want to see the number of activities that are tagged as unknown.

# Load the combined data from the CSV file

all_activities_data = pd.read_csv('all_activities_data.csv')

# Filter the data for activities tagged as 'unknown'
unknown_activities = all_activities_data[all_activities_data['activity_type'] == 'unknown']

# Drop duplicates based on the 'file_name' column
unknown_activities = unknown_activities.drop_duplicates(subset='file_name', keep='first')

# Display the required information
print("\nUnknown Activities:")
print(unknown_activities[['file_name', 'activity_type']])
print("\nNumber of unknown activities:", unknown_activities.shape[0])

unknown_activities.to_csv('unknown_activities.csv', index=False)
# Out:
# Unknown Activities:
# Empty DataFrame
# Columns: [file_name, activity_type]
# Index: []
#
# Number of unknown activities: 0
